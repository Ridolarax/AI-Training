# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# sns.set()

# %%
yield_df = pd.read_csv("./datasets/yield_df.csv", index_col=0)

# %%
yield_df.head()
# Out:
#       Area         Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  Albania        Maize  1990        36613                         1485.0
# 1  Albania     Potatoes  1990        66667                         1485.0
# 2  Albania  Rice, paddy  1990        23333                         1485.0
# 3  Albania      Sorghum  1990        12500                         1485.0
# 4  Albania     Soybeans  1990         7000                         1485.0
#
#    pesticides_tonnes  avg_temp
# 0              121.0     16.37
# 1              121.0     16.37
# 2              121.0     16.37
# 3              121.0     16.37
# 4              121.0     16.37

# %%
yield_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28242 entries, 0 to 28241
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area                           28242 non-null  object
#  1   Item                           28242 non-null  object
#  2   Year                           28242 non-null  int64
#  3   hg/ha_yield                    28242 non-null  int64
#  4   average_rain_fall_mm_per_year  28242 non-null  float64
#  5   pesticides_tonnes              28242 non-null  float64
#  6   avg_temp                       28242 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.7+ MB

# %%
yield_df.columns = [x.strip() for x in yield_df.columns]
dummy
# Out:
# ['Area',
#  'Item',
#  'Year',
#  'hg/ha_yield',
#  'average_rain_fall_mm_per_year',
#  'pesticides_tonnes',
#  'avg_temp']

# %% [markdown]
# ### Check for missing Values

# %%
yield_df.notnull().head()
# Out:
#    Area  Item  Year  hg/ha_yield  average_rain_fall_mm_per_year  \
# 0  True  True  True         True                           True
# 1  True  True  True         True                           True
# 2  True  True  True         True                           True
# 3  True  True  True         True                           True
# 4  True  True  True         True                           True
#
#    pesticides_tonnes  avg_temp
# 0               True      True
# 1               True      True
# 2               True      True
# 3               True      True
# 4               True      True

# %%
yield_df.isnull().sum()
# Out:
# Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %% [markdown]
# ### The data is clean and doesn't have missing value.
#
# ## Data Visualization of the Data

# %%
sns.pairplot(yield_df, height=3)
plt.show()

# %%
# Draw BoxPlot
sns.boxplot(data = yield_df["Year"])
plt.show()

# %%
sns.regplot(x= yield_df["average_rain_fall_mm_per_year"], y=yield_df["hg/ha_yield"])
plt.xlabel = 80
plt.show()

# %%
sns.regplot(x= yield_df["avg_temp"], y = yield_df["hg/ha_yield"])
plt.show()
